# %% [markdown]
# <a href="https://colab.research.google.com/github/varasrisiri/Machine-Learning-Course-Part_2/blob/main/4.1.4_Matrix_Operations_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing Numpy Library

# %%
import numpy as np

# %% [markdown]
# **Matrix Addition**

# %% [markdown]
# Two matrices can be added only if they have the same shape

# %%
#creating two matrices

A = np.array([[2,3],[4,5]])

B = np.array([[6,7],[8,9]])

print(A)
# Out:
# [[2 3]
#  [4 5]]

# %%
print(B)
# Out:
# [[6 7]
#  [8 9]]

# %%
A.shape
# Out:
# (2, 2)

# %%
B.shape
# Out:
# (2, 2)

# %% [markdown]
# Adding two Matrices

# %%
sum = A+B
print(sum)
# Out:
# [[ 8 10]
#  [12 14]]

# %%
#creating two matrices with random values
matrix_1 = np.random.randint(20,size = (3,3))
matrix_2 = np.random.randint(30, size = (3,3))

# %%
print(matrix_1)
# Out:
# [[ 1  4  9]
#  [ 2 13  3]
#  [ 8 12  1]]

# %%
print(matrix_2)
# Out:
# [[25 22  1]
#  [18 12 17]
#  [ 5 17  3]]

# %%
sum = np.add(matrix_1,matrix_2)

# %%
print(sum)
# Out:
# [[26 26 10]
#  [20 25 20]
#  [13 29  4]]

# %%
#creating two matrices with random values
matrix_3 = np.random.randint(20,size = (3,3))
matrix_4 = np.random.randint(30, size = (3,4))

# %%
sum_2 = np.add(matrix_3,matrix_4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1142/3223942002.py in <cell line: 0>()
# ----> 1 sum_2 = np.add(matrix_3,matrix_4)
#
# ValueError: operands could not be broadcast together with shapes (3,3) (3,4)

# %% [markdown]
# THIS ERROR IS BECAUSE THE SHAPE OF matrix_3,matrix_4 ARE DIFFERENT

# %% [markdown]
# **Matrix Subtraction**

# %%
#creating two matrices

A = np.array([[2,3],[4,5]])

B = np.array([[6,7],[8,9]])

# %%
print(A)
# Out:
# [[2 3]
#  [4 5]]

# %%
print(B)
# Out:
# [[6 7]
#  [8 9]]

# %%
Difference = A - B

# %%
print(Difference)
# Out:
# [[-4 -4]
#  [-4 -4]]

# %%
#creating two matrices with random values
matrix_A = np.random.randint(20,size = (3,3))
matrix_B = np.random.randint(30, size = (3,3))

# %%
print(matrix_A)
# Out:
# [[ 0 19 13]
#  [14 15 16]
#  [18  0  2]]

# %%
print(matrix_B)
# Out:
# [[19 28 20]
#  [16 26  4]
#  [ 6  7  5]]

# %%
diff = np.subtract(matrix_A,matrix_B)

# %%
print(diff)
# Out:
# [[-19  -9  -7]
#  [ -2 -11  12]
#  [ 12  -7  -3]]

# %%
#creating two matrices with random values
matrix_C = np.random.randint(20,size = (3,3))
matrix_D = np.random.randint(30, size = (3,4))

# %%
print(matrix_C)
# Out:
# [[ 5  5 16]
#  [16 15 12]
#  [10  6 19]]

# %%
print(matrix_D)
# Out:
# [[23 24 24 25]
#  [14  4 17  9]
#  [17 28 29 18]]

# %%
diff = np.subtract(matrix_C,matrix_D)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1142/4287982958.py in <cell line: 0>()
# ----> 1 diff = np.subtract(matrix_C,matrix_D)
#
# ValueError: operands could not be broadcast together with shapes (3,3) (3,4)

# %% [markdown]
# **Multiplying a matrix by a scalar**

# %%
x = 5
y = np.random.randint(10, size = (3,3))

print(y)
# Out:
# [[2 0 4]
#  [2 3 3]
#  [3 9 2]]

# %%
product = np.multiply(x,y)

# %%
print(product)
# Out:
# [[10  0 20]
#  [10 15 15]
#  [15 45 10]]

# %% [markdown]
# **Multiplying two matrices**

# %%
#creating two matrices with random values
matrix_1 = np.random.randint(5,size = (3,3))
matrix_2 = np.random.randint(5, size = (3,4))

# %%
print(matrix_1)
# Out:
# [[4 4 3]
#  [2 1 3]
#  [3 1 1]]

# %%
print(matrix_4)
# Out:
# [[29 18 13 26]
#  [28  5 19 20]
#  [17 13 23 12]]

# %%
product = np.dot(matrix_1,matrix_2)

# %%
print(product)
# Out:
# [[16 12 11 20]
#  [14  3  7 14]
#  [ 7  3  7  6]]

# %%
product.shape
# Out:
# (3, 4)

# %%
#creating two matrices with random values
matrix_3 = np.random.randint(5,size = (3,3))
matrix_4 = np.random.randint(5, size = (4,4))

# %%
product = np.dot(matrix_3,matrix_4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1142/1053040334.py in <cell line: 0>()
# ----> 1 product = np.dot(matrix_3,matrix_4)
#
# ValueError: shapes (3,3) and (4,4) not aligned: 3 (dim 1) != 4 (dim 0)

# %%
#creating two matrices with random values
matrix_5 = np.random.randint(5,size = (3,3))
matrix_6 = np.random.randint(5, size = (3,3))

# %%
print(matrix_5)
# Out:
# [[1 0 3]
#  [1 2 3]
#  [3 0 2]]

# %%
print(matrix_6)
# Out:
# [[0 2 4]
#  [1 1 4]
#  [2 3 4]]

# %%
product = np.multiply(matrix_5,matrix_6)

# %%
print(product)
# Out:
# [[ 0  0 12]
#  [ 1  2 12]
#  [ 6  0  8]]
